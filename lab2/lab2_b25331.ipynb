# %%
import numpy as a
import pandas as b

print(a.__version__)
print(b.__version__)
c = b.read_csv("lab2_machines.csv")
print(c.shape)
# Out:
# 1.26.4
# 2.2.3
# (300, 6)

# %%
d = c.isna().sum()
print(d)

e = c["needs_service"].value_counts()
print(e)

f = c["machine_type"].value_counts()
print(f)

g = c.groupby("needs_service").apply(lambda x: x.isna().sum())
print(g)
# Out:
# machine_type      0
# runtime_hours     0
# temperature      30
# vibration        23
# pressure         16
# needs_service     0
# dtype: int64
# needs_service
# 0    238
# 1     62
# Name: count, dtype: int64
# machine_type
# lathe    123
# mill      96
# drill     54
# press     27
# Name: count, dtype: int64
#                machine_type  runtime_hours  temperature  vibration  pressure  \
# needs_service
# 0                         0              0           19         13         7
# 1                         0              0           11         10         9
#
#                needs_service
# needs_service
# 0                          0
# 1                          0
# ...

# %%
h = c["temperature"].median()
i = c.groupby("needs_service")["temperature"].median()
print(h, i)

j = c.groupby("needs_service")["temperature"].transform("median")
k = c.copy()
k["temp_global"] = k["temperature"].fillna(h)
k["temp_group"] = k["temperature"].fillna(j)
# Out:
# 66.74000000000001 needs_service
# 0    65.12
# 1    88.80
# Name: temperature, dtype: float64

# %%
l = c["machine_type"].unique()
m = b.DataFrame()
for n in l:
    m[n] = (c["machine_type"] == n).astype(int)

o = b.get_dummies(c["machine_type"], dtype=int)
print((m.values == o.values).all())
# Out:
# False

# %%
def train_test_split(a_arr, b_arr, c_ratio=0.2, d_seed=42):
    e = a.random.default_rng(d_seed)
    f = a.array([], dtype=int)
    g = a.array([], dtype=int)
    h = a.unique(b_arr)
    for i in h:
        j = a.where(b_arr == i)[0]
        e.shuffle(j)
        k = int(len(j) * (1 - c_ratio))
        f = a.concatenate([f, j[:k]])
        g = a.concatenate([g, j[k:]])
    e.shuffle(f)
    e.shuffle(g)
    return a_arr[f], a_arr[g], b_arr[f], b_arr[g]

# %%
def confusion_matrix(a_true, b_pred):
    a_true = a.asarray(a_true)
    b_pred = a.asarray(b_pred)
    c = a.sum((a_true == 1) & (b_pred == 1))
    d = a.sum((a_true == 0) & (b_pred == 1))
    e = a.sum((a_true == 1) & (b_pred == 0))
    f = a.sum((a_true == 0) & (b_pred == 0))
    return a.array([[f, d], [e, c]])

def binary_metrics(a_true, b_pred):
    c = confusion_matrix(a_true, b_pred)
    d, e = c[0]
    f, g = c[1]
    h = g / (g + e) if (g + e) > 0 else 0.0
    i = g / (g + f) if (g + f) > 0 else 0.0
    j = (2 * h * i) / (h + i) if (h + i) > 0 else 0.0
    k = (g + d) / (d + e + f + g)
    return k, h, i, j

# %%
a_df = b.read_csv("lab2_machines.csv")

c_x = a_df.drop(columns=["needs_service"])
d_y = a_df["needs_service"].values

e, f, g, h = train_test_split(c_x.values, d_y, c_ratio=0.2, d_seed=42)

i = b.DataFrame(e, columns=c_x.columns)
j = b.DataFrame(f, columns=c_x.columns)

k = ["runtime_hours", "temperature", "vibration", "pressure"]
for l in k:
    m = i[l].median()
    i[l] = i[l].fillna(m)
    j[l] = j[l].fillna(m)

n = i["machine_type"].unique()
for o in n:
    i[o] = (i["machine_type"] == o).astype(int)
    j[o] = (j["machine_type"] == o).astype(int)

i = i.drop(columns=["machine_type"])
j = j.drop(columns=["machine_type"])

p = a.unique(g, return_counts=True)
q = p[0][a.argmax(p[1])]

r = a.full_like(h, fill_value=q)

s, t, u, v = binary_metrics(h, r)
print("Accuracy:", s)
print("Precision:", t)
print("Recall:", u)
print("F1:", v)
# Out:
# Accuracy: 0.7868852459016393
# Precision: 0.0
# Recall: 0.0
# F1: 0.0
# /tmp/ipykernel_67599/2915216375.py:14: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   i[l] = i[l].fillna(m)
# /tmp/ipykernel_67599/2915216375.py:15: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   j[l] = j[l].fillna(m)
# ...
